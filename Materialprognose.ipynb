# %% [markdown]
# # Modellierung der Vorhersage der Materialprognose
#
#
# Dieses Notebook beschäftigt sich mit der Entwicklung von Vorhersagemodellen für die Zielgröße. Hierzu werden verschiedene Featuresets und Modelle verwendet, um die bestmögliche Vorhersagegenauigkeit zu erreichen.

# %% [markdown]
# ## Einstellungen und Datenvorbereitung
#
# - **Import relevanter Bibliotheken**
# - **Metrik:** Die Leistung der Modelle wird anhand der `f1` bzw. `f1_weighted`-Metriken bewertet.
# - **Zielgröße (Target):** `Material_con`
# - **Irrelevante Spalten:** Diese Spalten werden aus dem Feature-Set entfernt, da sie für die Vorhersage nicht benötigt werden.

# %%
import pandas as pd
import os
from sklearn.model_selection import train_test_split, StratifiedKFold
from IPython.display import display, HTML
from helpers.model_utils import (load_and_prepare_data, 
                                 display_top_models_for_target, 
                                 train_and_tune_models_balanced,  
                                 compare_results_across_datasets, 
                                 display_final_confusion_matrices, 
                                 save_scores_to_csv, 
                                 analyze_model_performance, 
                                 filter_and_retrain_with_vif,
                                 direcetion_results,
                                 plot_scores_and_percent_diff,
                                 compare_smote_effects)
from helpers.model_pipelines import (define_pipelines_Material, 
                                     shap_analysis,load_and_split_data,
                                     shap_analysis_single_model)

# %%
# Einstellungen Notebook
target_name = "Materialprognose"

# Metrik auswählen
metric = "f1_weighted"  

# Zielgröße
target_column = 'Material_con'  
irrelevant_columns = ['Position_con', 'Ergebnis_con', 'Probenhoehe', 'richtig_verbaut', 'Zeit', 'VersuchID','umformzeit', 'synthetisch'
                      ]

# Einfluss der Verkippungssensoren
verkippungsfeatures = ["Verkippung_1", "Verkippung_2", "Verkippung_3", "Verkippung_4", 
                      "Verkippung_1_Min", "Verkippung_1_Max", "Verkippung_1_Mean", "Verkippung_1_Median", "Verkippung_1_Std", 
                      "Verkippung_2_Min","Verkippung_2_Max","Verkippung_2_Mean","Verkippung_2_Median","Verkippung_2_Std","Verkippung_3_Min",
                      "Verkippung_3_Max","Verkippung_3_Mean","Verkippung_3_Median","Verkippung_3_Std","Verkippung_4_Min","Verkippung_4_Max",
                      "Verkippung_4_Mean","Verkippung_4_Median","Verkippung_4_Std", "tilt_x_tiefster", "tilt_y_tiefster", "tilt_x_t0", "tilt_y_t0"]

# Mapping Pfad für Labels
label_mapping_path = "./data_preparation/mappings/label_mappings_binary.json"

# Verkippung berücksichtigen?
Verkippung = True
if not Verkippung:
    irrelevant_columns.extend(verkippungsfeatures)
    
# SHAP Analyse für ALLE Modelle durchführen?
shap_on = False
plot_type = 'summary'  # Alternativ: "summary", "bar" oder "interaction" oder "violin"
plot_type = str(plot_type)

# Plots speichern?
save_plots = True

# mit SMOTE (synthethische Erweiterung der Trainingsdaten)?
smote_on = True

# Bautiel Temperatur berücksichtigen?
bauteil_temp = True
if not bauteil_temp:
    irrelevant_columns.append('Bauteil_Temp')

# %%
# Pfade zu den balancierten Testdaten
test_filepath = f"./datasets/test_{target_column}.pkl"
if smote_on:
    # Pfade zu den balancierten Trainingsdaten
    train_filepath = f"./datasets/train_balanced_{target_column}_smote_2500.pkl"
    test_filepath = f"./datasets/test_{target_column}.pkl"
    # Lade und bereite Trainings- und Testdaten vor
    X_train_original, y_train = load_and_prepare_data(train_filepath, target_column, irrelevant_columns)
    X_test_original, y_test = load_and_prepare_data(test_filepath, target_column, irrelevant_columns)
else: 
    save_plots = False
    filepath = f"./datasets/new_features.pkl"
    X, y = load_and_split_data(filepath, target_column, irrelevant_columns)
    # Datenaufteilung
    X_train_original, X_test_original, y_train, y_test = train_test_split(X, y, test_size=0.2, stratify=y, random_state=42)

    
# Überprüfen der Shapes
print(f"Trainingsdaten: X_train={X_train_original.shape}, y_train={y_train.shape}")
print(f"Testdaten: X_test={X_test_original.shape}, y_test={y_test.shape}")

# Zentrale Pipeline und Parameter
target_pipeline = define_pipelines_Material()
pipelines, param_grids = target_pipeline

# Cross-Validation Setup
skf = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)

# Anzeige der Klassenverteilungen 
print("Klassenverteilung im Training:")
print(y_train.value_counts())
print("\nKlassenverteilung im Test:")
print(y_test.value_counts())
# Out:
# Trainingsdaten: X_train=(5000, 70), y_train=(5000,)
# Testdaten: X_test=(124, 70), y_test=(124,)
# Klassenverteilung im Training:
# Material_con
# 0.0    2500
# 1.0    2500
# Name: count, dtype: int64
#
# Klassenverteilung im Test:
# Material_con
# 1.0    89
# 0.0    35
# Name: count, dtype: int64

# %%
print(X_train_original.columns)
print(len(X_train_original.columns))
# Out:
# Index(['Berührzeit', 'Höhe_Wegmessung_Aufprall', 'Umformzeit',
#        'Tiefster_Punkt', 'Energie_Aufprall', 'Motorstrom_Durchschnitt',
#        'Energie_ab_Durchschnitt', 'Bauteil_Temp', 'Werkzeug_Temp',
#        'Wegmessung_Min', 'Wegmessung_Max', 'Wegmessung_Mean',
#        'Wegmessung_Median', 'Wegmessung_Std', 'Verkippung_1_Min',
#        'Verkippung_1_Max', 'Verkippung_1_Mean', 'Verkippung_1_Median',
#        'Verkippung_1_Std', 'Verkippung_2_Min', 'Verkippung_2_Max',
#        'Verkippung_2_Mean', 'Verkippung_2_Median', 'Verkippung_2_Std',
#        'Verkippung_3_Min', 'Verkippung_3_Max', 'Verkippung_3_Mean',
#        'Verkippung_3_Median', 'Verkippung_3_Std', 'Verkippung_4_Min',
#        'Verkippung_4_Max', 'Verkippung_4_Mean', 'Verkippung_4_Median',
#        'Verkippung_4_Std', 'Stoesselhub_Min', 'Stoesselhub_Max',
#        'Stoesselhub_Mean', 'Stoesselhub_Median', 'Stoesselhub_Std',
#        'Geschwindigkeit_Ges_Min', 'Geschwindigkeit_Ges_Max',
#        'Geschwindigkeit_Ges_Mean', 'Geschwindigkeit_Ges_Median',
#        'Geschwindigkeit_Ges_Std', 'Presskraft_dyn_Min', 'Presskraft_dyn_Max',
#        'Presskraft_dyn_Mean', 'Presskraft_dyn_Median', 'Presskraft_dyn_Std',
#        'Motorstrom_Min', 'Motorstrom_Max', 'Motorstrom_Mean',
#        'Motorstrom_Median', 'Motorstrom_Std', 'druckberuehrzeit',
#        'auftreffzeitpunkt', 'v_max', 'v_min', 'arbeit_ab', 'tilt_x_tiefster',
#        'tilt_y_tiefster', 'tilt_x_t0', 'tilt_y_t0', 'min_motorstrom',
#        'max_motorstrom', 'mean_motorstrom', 'auftreffposition',
#        'auftreffgeschwindigkeit', 'beruehrungsdauer', 'max_druck'],
#       dtype='object')
# 70

# %% [markdown]
# # Process Features Dataset
#
# In diesem Abschnitt wird das Datenset für die Prozessmerkmale vorbereitet und trainiert. Das Dataset wird angepasst, indem irrelevante Spalten entfernt und die relevanten Features extrahiert werden. Anschließend werden verschiedene Machine-Learning-Modelle trainiert, die darauf abzielen, die Zielgröße basierend auf den Prozessmerkmalen vorherzusagen.

# %%
# Einstellungen Dataset
dataset_name = "process_features"

target_dir, feature_importance_path, balance_suffix, feature_importance_path_best, target_dir_best, tilt_suffix, temp_suffix  = direcetion_results(dataset_name, target_name, smote_on, Verkippung, bauteil_temp)

# Auswahl der Process Features aus dem Dataset
columns_process_features = [
    "VersuchID",
    "Berührzeit",
    "Höhe_Wegmessung_Aufprall",
    "Umformzeit",
    "Tiefster_Punkt",
    "Energie_Aufprall",
    "Motorstrom_Durchschnitt",
    "Energie_ab_Durchschnitt",
    "Bauteil_Temp",
    "Werkzeug_Temp",
    "Material_con",
    "Position_con",
    "Ergebnis_con",
    "Probenhoehe",
]

# Sicherstellen, dass nur existierende Spalten verwendet werden
columns_to_keep_train = [col for col in columns_process_features if col in X_train_original.columns]

# X_train und X_test auf relevante Spalten beschränken
X_train = X_train_original[columns_to_keep_train]
X_test = X_test_original[columns_to_keep_train]

# Falls Fehler auftreten, können wir sicherstellen, dass alle Spalten korrekt bereinigt sind:
X_train.columns = X_train.columns.str.strip()  # Entferne führende und nachfolgende Leerzeichen
X_test.columns = X_test.columns.str.strip()

print("Bereinigte Spalten in X_train:", X_train.columns)
print("Bereinigte Spalten in X_test:", X_test.columns)
print(len(X_train.columns))
# Out:
# Bereinigte Spalten in X_train: Index(['Berührzeit', 'Höhe_Wegmessung_Aufprall', 'Umformzeit',
#        'Tiefster_Punkt', 'Energie_Aufprall', 'Motorstrom_Durchschnitt',
#        'Energie_ab_Durchschnitt', 'Bauteil_Temp', 'Werkzeug_Temp'],
#       dtype='object')
# Bereinigte Spalten in X_test: Index(['Berührzeit', 'Höhe_Wegmessung_Aufprall', 'Umformzeit',
#        'Tiefster_Punkt', 'Energie_Aufprall', 'Motorstrom_Durchschnitt',
#        'Energie_ab_Durchschnitt', 'Bauteil_Temp', 'Werkzeug_Temp'],
#       dtype='object')
# 9

# %% [markdown]
# ## Training
#
# In diesem Abschnitt wird das Training der Modelle durchgeführt. Die Modelle werden mit Hilfe von Cross-Validation optimiert, um eine robuste Bewertung der Modellleistung sicherzustellen. Hyperparameter-Tuning wird genutzt, um die besten Einstellungen für jedes Modell zu finden und die Generalisierungsfähigkeit auf Testdaten zu verbessern.

# %%
# Modelltraining und Bewertung
best_pipelines, results, confusion_matrices1 = train_and_tune_models_balanced(
    pipelines, 
    param_grids, 
    X_train, 
    y_train, 
    skf, 
    X_test=X_test, 
    y_test=y_test
)

# Ergebnisse in DataFrame speichern
results_df_1 = pd.DataFrame.from_dict(results, orient='index').T
#results_df.drop(['best_params'], axis=0, inplace=True)

# Ergebnisse in tabellarischer Form anzeigen
display(HTML(results_df_1.to_html()))

#results_df_1.drop(['best_params'], axis=0, inplace=True)
# Ergebnisse speichern
save_scores_to_csv(
    results=results_df_1,  # Direkt das DataFrame übergeben
    output_dir=target_dir,    # Zielverzeichnis
    file_name=f"model_scores_{dataset_name}{balance_suffix}.csv",  # Dateiname
    Verkippung=Verkippung    # Flag für Verkippung
)
# Out:
# Training XGBoost...
# Fitting 5 folds for each of 81 candidates, totalling 405 fits
# Berechnung der finalen Scores für XGBoost...
# Training AdaBoost...
# Fitting 5 folds for each of 18 candidates, totalling 90 fits
# Berechnung der finalen Scores für AdaBoost...
# Training Random Forest...
# Fitting 5 folds for each of 81 candidates, totalling 405 fits
# Berechnung der finalen Scores für Random Forest...
# Training SVM...
# Fitting 5 folds for each of 9 candidates, totalling 45 fits
# Berechnung der finalen Scores für SVM...
# Training kNN...
# Fitting 5 folds for each of 4 candidates, totalling 20 fits
# Berechnung der finalen Scores für kNN...
# Training Logistische Regression...
# Fitting 5 folds for each of 16 candidates, totalling 80 fits
# Berechnung der finalen Scores für Logistische Regression...
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>XGBoost</th>
#       <th>AdaBoost</th>
#       <th>Random Forest</th>
#       <th>SVM</th>
#       <th>kNN</th>
#       <th>Logistische Regression</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>accuracy</th>
#       <td>0.887097</td>
#       <td>0.887097</td>
#       <td>0.895161</td>
#       <td>0.782258</td>
#       <td>0.798387</td>
#       <td>0.580645</td>
#     </tr>
#     <tr>
#       <th>precision</th>
#       <td>0.941176</td>
#       <td>0.941176</td>
#       <td>0.952381</td>
#       <td>0.844444</td>
#       <td>0.921053</td>
#       <td>0.768116</td>
#     </tr>
#     <tr>
#       <th>recall</th>
#       <td>0.898876</td>
#       <td>0.898876</td>
#       <td>0.898876</td>
#       <td>0.853933</td>
#       <td>0.786517</td>
#       <td>0.595506</td>
#     </tr>
#     <tr>
#       <th>f1</th>
#       <td>0.91954</td>
#       <td>0.91954</td>
#       <td>0.924855</td>
#       <td>0.849162</td>
#       <td>0.848485</td>
#       <td>0.670886</td>
#     </tr>
#     <tr>
#       <th>f1_weighted</th>
#       <td>0.88885</td>
#       <td>0.88885</td>
#       <td>0.897141</td>
#       <td>0.781288</td>
#       <td>0.806234</td>
#       <td>0.600699</td>
#     </tr>
#     <tr>
#       <th>roc_auc</th>
#       <td>0.951846</td>
#       <td>0.950241</td>
#       <td>0.943178</td>
#       <td>0.830498</td>
#       <td>0.807544</td>
#       <td>0.633708</td>
#     </tr>
#     <tr>
#       <th>percent_diff_accuracy</th>
#       <td>11.272577</td>
#       <td>10.898275</td>
#       <td>9.323208</td>
#       <td>1.652242</td>
#       <td>20.145319</td>
#       <td>14.711345</td>
#     </tr>
#     <tr>
#       <th>percent_diff_precision</th>
#       <td>5.882353</td>
#       <td>5.278551</td>
#       <td>4.761905</td>
#       <td>10.931433</td>
#       <td>7.894737</td>
#       <td>13.60147</td>
#     </tr>
#     <tr>
#       <th>percent_diff_recall</th>
#       <td>10.07639</td>
#       <td>9.89611</td>
#       <td>7.75078</td>
#       <td>0.797795</td>
#       <td>21.316841</td>
#       <td>14.192274</td>
#     </tr>
#     <tr>
#       <th>percent_diff_f1</th>
#       <td>8.027579</td>
#       <td>7.640406</td>
#       <td>6.299534</td>
#       <td>5.099583</td>
#       <td>15.134539</td>
#       <td>2.0545</td>
#     </tr>
#     <tr>
#       <th>percent_diff_f1_weighted</th>
#       <td>11.097172</td>
#       <td>10.722128</td>
#       <td>9.122487</td>
#       <td>1.665493</td>
#       <td>19.360499</td>
#       <td>11.758551</td>
#     </tr>
#     <tr>
#       <th>percent_diff_roc_auc</th>
#       <td>4.815409</td>
#       <td>4.962815</td>
#       <td>5.680915</td>
#       <td>6.178615</td>
#       <td>19.245573</td>
#       <td>14.976833</td>
#     </tr>
#     <tr>
#       <th>best_params</th>
#       <td>{'clf__gamma': 0.05, 'clf__learning_rate': 0.1, 'clf__max_depth': 5, 'clf__n_estimators': 70}</td>
#       <td>{'clf__estimator': DecisionTreeClassifier(max_depth=4), 'clf__learning_rate': 0.25, 'clf__n_estimators': 21}</td>
#       <td>{'clf__max_depth': 7, 'clf__min_samples_leaf': 1, 'clf__min_samples_split': 7, 'clf__n_estimators': 60}</td>
#       <td>{'clf__C': 0.5, 'clf__gamma': 0.01, 'clf__kernel': 'rbf'}</td>
#       <td>{'clf__n_neighbors': 3, 'clf__weights': 'uniform'}</td>
#       <td>{'clf__C': 5, 'clf__max_iter': 500, 'clf__solver': 'lbfgs'}</td>
#     </tr>
#   </tbody>
# </table>
# Scores erfolgreich gespeichert unter: results/Materialprognose//process_features/model_scores_process_features.csv

# %% [markdown]
# ## Confusion Matrices
#
# In diesem Abschnitt werden die Confusion-Matrices der Modelle analysiert. Diese bieten eine detaillierte Übersicht über die Vorhersagegenauigkeit der Modelle und ermöglichen es, Fehlklassifikationen zu identifizieren. Durchschnittliche Confusion-Matrices über alle Cross-Validation-Folds werden erstellt, visualisiert und optional gespeichert, um die Klassifikationsleistung der Modelle besser zu bewerten.

# %%
# Normalisierte durchschnittliche Confusion-Matrices anzeigen
display_final_confusion_matrices(
    confusion_matrices1,
    label_mapping_path=label_mapping_path,
    target_column=target_column,  # Zielspalte hinzufügen
    target_dir=target_dir,
    save_plots=save_plots,
    normalize=True,  # Optional
    Verkippung=Verkippung
)
# Out:
# Confusion-Matrix für XGBoost (Testdaten):
# Confusion-Matrix für XGBoost gespeichert unter: results/Materialprognose//process_features/XGBoost/final_confusion_matrix.svg
# Confusion-Matrix für AdaBoost (Testdaten):
# Confusion-Matrix für AdaBoost gespeichert unter: results/Materialprognose//process_features/AdaBoost/final_confusion_matrix.svg
# Confusion-Matrix für Random Forest (Testdaten):
# Confusion-Matrix für Random Forest gespeichert unter: results/Materialprognose//process_features/Random Forest/final_confusion_matrix.svg
# Confusion-Matrix für SVM (Testdaten):
# Confusion-Matrix für SVM gespeichert unter: results/Materialprognose//process_features/SVM/final_confusion_matrix.svg
# Confusion-Matrix für kNN (Testdaten):
# Confusion-Matrix für kNN gespeichert unter: results/Materialprognose//process_features/kNN/final_confusion_matrix.svg
# Confusion-Matrix für Logistische Regression (Testdaten):
# Confusion-Matrix für Logistische Regression gespeichert unter: results/Materialprognose//process_features/Logistische Regression/final_confusion_matrix.svg

# %% [markdown]
# ## Overfitting Test
#
# In diesem Abschnitt wird die Überprüfung von Overfitting durch die Analyse von Learning Curves und Validation Curves durchgeführt, um den Bias-Variance-Tradeoff besser zu verstehen. Die `analyze_model_performance` Funktion aus der `model_pipelines.py` führt diese Analysen durch und erstellt entsprechende Plots. Es werden sowohl die Trainingsscores als auch die Testscores über verschiedene Größen des Trainingssets und Hyperparameterbereiche betrachtet, um die Modellstabilität und die Generalisierungsfähigkeit zu bewerten. Dies hilft dabei, die optimale Komplexität der Modelle zu bestimmen und sicherzustellen, dass sie gut auf unbekannte Daten generalisieren.

# %%
# Overfitting überprüfen 
# Analyse von Learning Curves für Bias-Variance-Tradeoff
print(f"\nLearning Curve Analyse für {target_name}:")

# Analyse der Modellleistung
analyze_model_performance(
    pipelines=pipelines, 
    param_grids=param_grids, 
    X=X_train, 
    y=y_train, 
    scoring='f1', 
    cv=skf,
    save_plots=save_plots,
    output_dir= target_dir,
    Verkippung=Verkippung
)
# Out:
# Learning Curve Analyse für Materialprognose:
# Analysiere Modell: XGBoost...
# Erstelle Validation Curve für XGBoost...
# Validation Curve gespeichert unter: results/Materialprognose//process_features/XGBoost/validation_curve_XGBoost_clf__n_estimators.svg
# Erstelle Learning Curve für XGBoost...
# Learning Curve gespeichert unter: results/Materialprognose//process_features/XGBoost/learning_curve_XGBoost.svg
# Analysiere Modell: AdaBoost...
# Erstelle Validation Curve für AdaBoost...
# Validation Curve gespeichert unter: results/Materialprognose//process_features/AdaBoost/validation_curve_AdaBoost_clf__n_estimators.svg
# Erstelle Learning Curve für AdaBoost...
# Learning Curve gespeichert unter: results/Materialprognose//process_features/AdaBoost/learning_curve_AdaBoost.svg
# Analysiere Modell: Random Forest...
# Erstelle Validation Curve für Random Forest...
# Validation Curve gespeichert unter: results/Materialprognose//process_features/Random Forest/validation_curve_Random Forest_clf__n_estimators.svg
# Erstelle Learning Curve für Random Forest...
# Learning Curve gespeichert unter: results/Materialprognose//process_features/Random Forest/learning_curve_Random Forest.svg
# Analysiere Modell: SVM...
# Erstelle Validation Curve für SVM...
# Validation Curve gespeichert unter: results/Materialprognose//process_features/SVM/validation_curve_SVM_clf__C.svg
# Erstelle Learning Curve für SVM...
# Learning Curve gespeichert unter: results/Materialprognose//process_features/SVM/learning_curve_SVM.svg
# Analysiere Modell: kNN...
# Erstelle Validation Curve für kNN...
# Validation Curve gespeichert unter: results/Materialprognose//process_features/kNN/validation_curve_kNN_clf__n_neighbors.svg
# Erstelle Learning Curve für kNN...
# Learning Curve gespeichert unter: results/Materialprognose//process_features/kNN/learning_curve_kNN.svg
# Analysiere Modell: Logistische Regression...
# Erstelle Validation Curve für Logistische Regression...
# Validation Curve gespeichert unter: results/Materialprognose//process_features/Logistische Regression/validation_curve_Logistische Regression_clf__C.svg
# Erstelle Learning Curve für Logistische Regression...
# Learning Curve gespeichert unter: results/Materialprognose//process_features/Logistische Regression/learning_curve_Logistische Regression.svg

# %% [markdown]
# ## SHAP-Analyse
#
# In diesem Abschnitt führen wir eine SHAP-Analyse durch, um die Einflüsse der einzelnen Features auf die Vorhersagen der besten Modelle zu verstehen. Die Ergebnisse dieser Analyse helfen uns, die Modellentscheidungen transparenter zu machen. Anschließend laden wir Diagramme, die die besten drei Modelle basierend auf unterschiedlichen Metriken darstellen. Diese Visualisierungen unterstützen die Bewertung der Modellperformance und die Identifizierung von Schlüsselfeatures, die die Zielgröße beeinflussen.

# %%
# SHAP-Analyse
if shap_on:
    shap_analysis(
    best_pipelines=best_pipelines,  # Das Dictionary der besten Pipelines
    X_train=X_train,  # Die Trainingsdaten
    target_name = target_name,  # Der Zielname, z. B. für das Modellieren des Zielwerts
    dataset_name= dataset_name,  # Der Name des Datensets
    output_dir= target_dir,  # Optional: Basisverzeichnis für die Ergebnisse
    plot_type=plot_type,
    save_plots=save_plots,  # Angabe, ob die Diagramme gespeichert werden sollen
    verkippung = Verkippung
)

# %%
# Alle Diagramme aus der Zielgröße laden
display_top_models_for_target(
    target_dir,
    results_df_1,
    metric,
    verkippung=Verkippung,
    top_n=3  # Nur die besten 3 Modelle anzeigen
)
# Out:
# Top-3 Modelle basierend auf der Metrik 'f1_weighted':
# Random Forest    0.897141
# XGBoost           0.88885
# AdaBoost          0.88885
# Name: f1_weighted, dtype: object
#
# Top-3 Modelle basierend auf der gewichteten Metrik 'f1_weighted':
# Random Forest    0.897141
# XGBoost           0.88885
# AdaBoost          0.88885
# Name: f1_weighted, dtype: object
#
# Top-3 Modelle basierend auf der gewichteten Metrik 'percent_diff_f1_weighted':
# kNN                       19.360499
# Logistische Regression    11.758551
# XGBoost                   11.097172
# Name: percent_diff_f1_weighted, dtype: object
#
# Anzeigen der SHAP-Diagramme für Modelle in den Top-3 (zusammengefasst): Random Forest, Logistische Regression, XGBoost, kNN, AdaBoost
# SHAP-Diagramm für Random Forest nicht gefunden unter results/Materialprognose//process_features/Random Forest/shap_summary_Random Forest.svg.
# SHAP-Diagramm für Logistische Regression nicht gefunden unter results/Materialprognose//process_features/Logistische Regression/shap_summary_Logistische Regression.svg.
# SHAP-Diagramm für XGBoost nicht gefunden unter results/Materialprognose//process_features/XGBoost/shap_summary_XGBoost.svg.
# SHAP-Diagramm für kNN nicht gefunden unter results/Materialprognose//process_features/kNN/shap_summary_kNN.svg.
# SHAP-Diagramm für AdaBoost nicht gefunden unter results/Materialprognose//process_features/AdaBoost/shap_summary_AdaBoost.svg.

# %%
# if shap_on:
#     feature_importances, irrelevant_features = extract_feature_importance_from_shap(
#         best_pipelines=best_pipelines,
#         X_train=X_train,
#         target_name=target_name,
#         dataset_name=dataset_name,
#         output_dir=target_dir,
#         verkippung=Verkippung,
#         importance_threshold=0.01,
#         save_results=save_plots
#     )

#     # Ausgabe der irrelevanten Features
#     print("Irrelevante Features:", irrelevant_features)

# %% [markdown]
# # Aggregierte Daten

# %%
# Einstellungen
dataset_name = "aggregated_features"

target_dir, feature_importance_path, balance_suffix, feature_importance_path_best, target_dir_best, tilt_suffix, temp_suffix  = direcetion_results(dataset_name, target_name, smote_on, Verkippung, bauteil_temp)

# Auswahl der Process Features aus dem Dataset
columns_aggregated_features = [
    "VersuchID",
    "Berührzeit",
    "Höhe_Wegmessung_Aufprall",
    "Umformzeit",
    "Tiefster_Punkt",
    "Energie_Aufprall",
    "Motorstrom_Durchschnitt",
    "Energie_ab_Durchschnitt",
    "Bauteil_Temp",
    "Werkzeug_Temp",
    "Material_con",
    "Position_con",
    "Ergebnis_con",
    "Probenhoehe",
    "richtig_verbaut",
    "Wegmessung_Min",
    "Wegmessung_Max",
    "Wegmessung_Mean",
    "Wegmessung_Median",
    "Wegmessung_Std",
    "Verkippung_1_Min",
    "Verkippung_1_Max",
    "Verkippung_1_Mean",
    "Verkippung_1_Median",
    "Verkippung_1_Std",
    "Verkippung_2_Min",
    "Verkippung_2_Max",
    "Verkippung_2_Mean",
    "Verkippung_2_Median",
    "Verkippung_2_Std",
    "Verkippung_3_Min",
    "Verkippung_3_Max",
    "Verkippung_3_Mean",
    "Verkippung_3_Median",
    "Verkippung_3_Std",
    "Verkippung_4_Min",
    "Verkippung_4_Max",
    "Verkippung_4_Mean",
    "Verkippung_4_Median",
    "Verkippung_4_Std",
    "Stoesselhub_Min",
    "Stoesselhub_Max",
    "Stoesselhub_Mean",
    "Stoesselhub_Median",
    "Stoesselhub_Std",
    "Geschwindigkeit_Ges_Min",
    "Geschwindigkeit_Ges_Max",
    "Geschwindigkeit_Ges_Mean",
    "Geschwindigkeit_Ges_Median",
    "Geschwindigkeit_Ges_Std",
    "Presskraft_dyn_Min",
    "Presskraft_dyn_Max",
    "Presskraft_dyn_Mean",
    "Presskraft_dyn_Median",
    "Presskraft_dyn_Std",
    "Motorstrom_Min",
    "Motorstrom_Max",
    "Motorstrom_Mean",
    "Motorstrom_Median",
    "Motorstrom_Std",
]

# Sicherstellen, dass nur existierende Spalten verwendet werden
columns_to_keep_train = [col for col in columns_aggregated_features if col in X_train_original.columns]

# X_train und X_test auf relevante Spalten beschränken
X_train = X_train_original[columns_to_keep_train]
X_test = X_test_original[columns_to_keep_train]

# Falls Fehler auftreten, können wir sicherstellen, dass alle Spalten korrekt bereinigt sind:
X_train.columns = X_train.columns.str.strip()  # Entferne führende und nachfolgende Leerzeichen
X_test.columns = X_test.columns.str.strip()

print("Bereinigte Spalten in X_train:", X_train.columns)
print("Bereinigte Spalten in X_test:", X_test.columns)
print(len(X_train.columns))
# Out:
# Bereinigte Spalten in X_train: Index(['Berührzeit', 'Höhe_Wegmessung_Aufprall', 'Umformzeit',
#        'Tiefster_Punkt', 'Energie_Aufprall', 'Motorstrom_Durchschnitt',
#        'Energie_ab_Durchschnitt', 'Bauteil_Temp', 'Werkzeug_Temp',
#        'Wegmessung_Min', 'Wegmessung_Max', 'Wegmessung_Mean',
#        'Wegmessung_Median', 'Wegmessung_Std', 'Verkippung_1_Min',
#        'Verkippung_1_Max', 'Verkippung_1_Mean', 'Verkippung_1_Median',
#        'Verkippung_1_Std', 'Verkippung_2_Min', 'Verkippung_2_Max',
#        'Verkippung_2_Mean', 'Verkippung_2_Median', 'Verkippung_2_Std',
#        'Verkippung_3_Min', 'Verkippung_3_Max', 'Verkippung_3_Mean',
#        'Verkippung_3_Median', 'Verkippung_3_Std', 'Verkippung_4_Min',
#        'Verkippung_4_Max', 'Verkippung_4_Mean', 'Verkippung_4_Median',
#        'Verkippung_4_Std', 'Stoesselhub_Min', 'Stoesselhub_Max',
#        'Stoesselhub_Mean', 'Stoesselhub_Median', 'Stoesselhub_Std',
#        'Geschwindigkeit_Ges_Min', 'Geschwindigkeit_Ges_Max',
#        'Geschwindigkeit_Ges_Mean', 'Geschwindigkeit_Ges_Median',
#        'Geschwindigkeit_Ges_Std', 'Presskraft_dyn_Min', 'Presskraft_dyn_Max',
#        'Presskraft_dyn_Mean', 'Presskraft_dyn_Median', 'Presskraft_dyn_Std',
#        'Motorstrom_Min', 'Motorstrom_Max', 'Motorstrom_Mean',
#        'Motorstrom_Median', 'Motorstrom_Std'],
#       dtype='object')
# Bereinigte Spalten in X_test: Index(['Berührzeit', 'Höhe_Wegmessung_Aufprall', 'Umformzeit',
#        'Tiefster_Punkt', 'Energie_Aufprall', 'Motorstrom_Durchschnitt',
#        'Energie_ab_Durchschnitt', 'Bauteil_Temp', 'Werkzeug_Temp',
#        'Wegmessung_Min', 'Wegmessung_Max', 'Wegmessung_Mean',
#        'Wegmessung_Median', 'Wegmessung_Std', 'Verkippung_1_Min',
#        'Verkippung_1_Max', 'Verkippung_1_Mean', 'Verkippung_1_Median',
#        'Verkippung_1_Std', 'Verkippung_2_Min', 'Verkippung_2_Max',
#        'Verkippung_2_Mean', 'Verkippung_2_Median', 'Verkippung_2_Std',
#        'Verkippung_3_Min', 'Verkippung_3_Max', 'Verkippung_3_Mean',
#        'Verkippung_3_Median', 'Verkippung_3_Std', 'Verkippung_4_Min',
#        'Verkippung_4_Max', 'Verkippung_4_Mean', 'Verkippung_4_Median',
#        'Verkippung_4_Std', 'Stoesselhub_Min', 'Stoesselhub_Max',
#        'Stoesselhub_Mean', 'Stoesselhub_Median', 'Stoesselhub_Std',
#        'Geschwindigkeit_Ges_Min', 'Geschwindigkeit_Ges_Max',
#        'Geschwindigkeit_Ges_Mean', 'Geschwindigkeit_Ges_Median',
#        'Geschwindigkeit_Ges_Std', 'Presskraft_dyn_Min', 'Presskraft_dyn_Max',
#        'Presskraft_dyn_Mean', 'Presskraft_dyn_Median', 'Presskraft_dyn_Std',
#        'Motorstrom_Min', 'Motorstrom_Max', 'Motorstrom_Mean',
#        'Motorstrom_Median', 'Motorstrom_Std'],
#       dtype='object')
# 54

# %% [markdown]
# ## Training

# %%
# Modelltraining und Bewertung
best_pipelines, results, confusion_matrices2 = train_and_tune_models_balanced(pipelines, 
    param_grids, 
    X_train, 
    y_train, 
    skf, 
    X_test=X_test, 
    y_test=y_test
)

# Ergebnisse in DataFrame speichern
results_df_2 = pd.DataFrame.from_dict(results, orient='index').T
#results_df.drop(['best_params'], axis=0, inplace=True)

# Ergebnisse in tabellarischer Form anzeigen
display(HTML(results_df_2.to_html()))

save_scores_to_csv(
    results=results_df_2,  # DataFrame mit den Scores
    output_dir=target_dir,
    file_name=f"model_scores_{dataset_name}{balance_suffix}.csv",  # Gemeinsamer Basisname
    Verkippung=Verkippung  # Fügt den '_no_tilt'-Suffix hinzu, falls nötig
)
# Out:
# Training XGBoost...
# Fitting 5 folds for each of 81 candidates, totalling 405 fits
# Berechnung der finalen Scores für XGBoost...
# Training AdaBoost...
# Fitting 5 folds for each of 18 candidates, totalling 90 fits
# Berechnung der finalen Scores für AdaBoost...
# Training Random Forest...
# Fitting 5 folds for each of 81 candidates, totalling 405 fits
# Berechnung der finalen Scores für Random Forest...
# Training SVM...
# Fitting 5 folds for each of 9 candidates, totalling 45 fits
# Berechnung der finalen Scores für SVM...
# Training kNN...
# Fitting 5 folds for each of 4 candidates, totalling 20 fits
# Berechnung der finalen Scores für kNN...
# Training Logistische Regression...
# Fitting 5 folds for each of 16 candidates, totalling 80 fits
# /opt/anaconda3/envs/conda310/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/anaconda3/envs/conda310/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/anaconda3/envs/conda310/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/anaconda3/envs/conda310/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/anaconda3/envs/conda310/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/anaconda3/envs/conda310/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/anaconda3/envs/conda310/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/anaconda3/envs/conda310/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/anaconda3/envs/conda310/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/anaconda3/envs/conda310/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/anaconda3/envs/conda310/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/anaconda3/envs/conda310/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/anaconda3/envs/conda310/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/anaconda3/envs/conda310/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/anaconda3/envs/conda310/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/anaconda3/envs/conda310/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/anaconda3/envs/conda310/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/anaconda3/envs/conda310/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/anaconda3/envs/conda310/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /opt/anaconda3/envs/conda310/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/anaconda3/envs/conda310/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/anaconda3/envs/conda310/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/anaconda3/envs/conda310/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/anaconda3/envs/conda310/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/anaconda3/envs/conda310/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/anaconda3/envs/conda310/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/anaconda3/envs/conda310/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/anaconda3/envs/conda310/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/anaconda3/envs/conda310/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/anaconda3/envs/conda310/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/anaconda3/envs/conda310/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/anaconda3/envs/conda310/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/anaconda3/envs/conda310/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/anaconda3/envs/conda310/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/anaconda3/envs/conda310/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/anaconda3/envs/conda310/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/anaconda3/envs/conda310/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/anaconda3/envs/conda310/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/anaconda3/envs/conda310/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/anaconda3/envs/conda310/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/anaconda3/envs/conda310/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# Berechnung der finalen Scores für Logistische Regression...
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>XGBoost</th>
#       <th>AdaBoost</th>
#       <th>Random Forest</th>
#       <th>SVM</th>
#       <th>kNN</th>
#       <th>Logistische Regression</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>accuracy</th>
#       <td>0.903226</td>
#       <td>0.943548</td>
#       <td>0.943548</td>
#       <td>0.919355</td>
#       <td>0.879032</td>
#       <td>0.887097</td>
#     </tr>
#     <tr>
#       <th>precision</th>
#       <td>0.963855</td>
#       <td>0.976744</td>
#       <td>0.976744</td>
#       <td>0.924731</td>
#       <td>0.9625</td>
#       <td>0.951807</td>
#     </tr>
#     <tr>
#       <th>recall</th>
#       <td>0.898876</td>
#       <td>0.94382</td>
#       <td>0.94382</td>
#       <td>0.966292</td>
#       <td>0.865169</td>
#       <td>0.88764</td>
#     </tr>
#     <tr>
#       <th>f1</th>
#       <td>0.930233</td>
#       <td>0.96</td>
#       <td>0.96</td>
#       <td>0.945055</td>
#       <td>0.911243</td>
#       <td>0.918605</td>
#     </tr>
#     <tr>
#       <th>f1_weighted</th>
#       <td>0.905358</td>
#       <td>0.944224</td>
#       <td>0.944224</td>
#       <td>0.917797</td>
#       <td>0.882702</td>
#       <td>0.889584</td>
#     </tr>
#     <tr>
#       <th>roc_auc</th>
#       <td>0.953933</td>
#       <td>0.962279</td>
#       <td>0.960835</td>
#       <td>0.963724</td>
#       <td>0.889727</td>
#       <td>0.942215</td>
#     </tr>
#     <tr>
#       <th>percent_diff_accuracy</th>
#       <td>9.677419</td>
#       <td>5.645161</td>
#       <td>5.037401</td>
#       <td>3.873396</td>
#       <td>12.096774</td>
#       <td>5.948179</td>
#     </tr>
#     <tr>
#       <th>percent_diff_precision</th>
#       <td>3.614458</td>
#       <td>2.325581</td>
#       <td>2.325581</td>
#       <td>4.508471</td>
#       <td>3.75</td>
#       <td>0.950474</td>
#     </tr>
#     <tr>
#       <th>percent_diff_recall</th>
#       <td>10.11236</td>
#       <td>5.617978</td>
#       <td>4.394224</td>
#       <td>2.404847</td>
#       <td>13.483146</td>
#       <td>5.930431</td>
#     </tr>
#     <tr>
#       <th>percent_diff_f1</th>
#       <td>6.976744</td>
#       <td>4.0</td>
#       <td>3.377634</td>
#       <td>1.127783</td>
#       <td>8.87574</td>
#       <td>2.609994</td>
#     </tr>
#     <tr>
#       <th>percent_diff_f1_weighted</th>
#       <td>9.464208</td>
#       <td>5.577552</td>
#       <td>4.969331</td>
#       <td>4.035538</td>
#       <td>11.729821</td>
#       <td>5.684452</td>
#     </tr>
#     <tr>
#       <th>percent_diff_roc_auc</th>
#       <td>4.606742</td>
#       <td>3.772071</td>
#       <td>3.916533</td>
#       <td>2.907837</td>
#       <td>11.027287</td>
#       <td>4.5281</td>
#     </tr>
#     <tr>
#       <th>best_params</th>
#       <td>{'clf__gamma': 0.05, 'clf__learning_rate': 0.05, 'clf__max_depth': 8, 'clf__n_estimators': 70}</td>
#       <td>{'clf__estimator': DecisionTreeClassifier(max_depth=4), 'clf__learning_rate': 0.25, 'clf__n_estimators': 21}</td>
#       <td>{'clf__max_depth': 7, 'clf__min_samples_leaf': 1, 'clf__min_samples_split': 7, 'clf__n_estimators': 60}</td>
#       <td>{'clf__C': 0.5, 'clf__gamma': 0.01, 'clf__kernel': 'rbf'}</td>
#       <td>{'clf__n_neighbors': 3, 'clf__weights': 'uniform'}</td>
#       <td>{'clf__C': 50, 'clf__max_iter': 500, 'clf__solver': 'lbfgs'}</td>
#     </tr>
#   </tbody>
# </table>
# Scores erfolgreich gespeichert unter: results/Materialprognose//aggregated_features/model_scores_aggregated_features.csv

# %% [markdown]
# ## Confusion Matrices

# %%
# Normalisierte durchschnittliche Confusion-Matrices anzeigen
display_final_confusion_matrices(
    confusion_matrices2,
    label_mapping_path=label_mapping_path,
    target_column=target_column,  # Zielspalte hinzufügen
    target_dir=target_dir,
    save_plots=save_plots,
    normalize=True,  # Optional
    Verkippung=Verkippung
)
# Out:
# Confusion-Matrix für XGBoost (Testdaten):
# Confusion-Matrix für XGBoost gespeichert unter: results/Materialprognose//aggregated_features/XGBoost/final_confusion_matrix.svg
# Confusion-Matrix für AdaBoost (Testdaten):
# Confusion-Matrix für AdaBoost gespeichert unter: results/Materialprognose//aggregated_features/AdaBoost/final_confusion_matrix.svg
# Confusion-Matrix für Random Forest (Testdaten):
# Confusion-Matrix für Random Forest gespeichert unter: results/Materialprognose//aggregated_features/Random Forest/final_confusion_matrix.svg
# Confusion-Matrix für SVM (Testdaten):
# Confusion-Matrix für SVM gespeichert unter: results/Materialprognose//aggregated_features/SVM/final_confusion_matrix.svg
# Confusion-Matrix für kNN (Testdaten):
# Confusion-Matrix für kNN gespeichert unter: results/Materialprognose//aggregated_features/kNN/final_confusion_matrix.svg
# Confusion-Matrix für Logistische Regression (Testdaten):
# Confusion-Matrix für Logistische Regression gespeichert unter: results/Materialprognose//aggregated_features/Logistische Regression/final_confusion_matrix.svg

# %% [markdown]
# ## Overfitting Test

# %%
# Overfitting überprüfen 
# Analyse von Learning Curves für Bias-Variance-Tradeoff
print(f"\nLearning Curve Analyse für {target_name}:")

# Analyse der Modellleistung
analyze_model_performance(
    pipelines=pipelines, 
    param_grids=param_grids, 
    X=X_train, 
    y=y_train, 
    scoring='f1', 
    cv=skf,
    save_plots=save_plots,
    output_dir= target_dir,
    Verkippung=Verkippung
)
# Out:
# Learning Curve Analyse für Materialprognose:
# Analysiere Modell: XGBoost...
# Erstelle Validation Curve für XGBoost...
# Validation Curve gespeichert unter: results/Materialprognose//aggregated_features/XGBoost/validation_curve_XGBoost_clf__n_estimators.svg
# Erstelle Learning Curve für XGBoost...
# Learning Curve gespeichert unter: results/Materialprognose//aggregated_features/XGBoost/learning_curve_XGBoost.svg
# Analysiere Modell: AdaBoost...
# Erstelle Validation Curve für AdaBoost...
# Validation Curve gespeichert unter: results/Materialprognose//aggregated_features/AdaBoost/validation_curve_AdaBoost_clf__n_estimators.svg
# Erstelle Learning Curve für AdaBoost...
# Learning Curve gespeichert unter: results/Materialprognose//aggregated_features/AdaBoost/learning_curve_AdaBoost.svg
# Analysiere Modell: Random Forest...
# Erstelle Validation Curve für Random Forest...
# Validation Curve gespeichert unter: results/Materialprognose//aggregated_features/Random Forest/validation_curve_Random Forest_clf__n_estimators.svg
# Erstelle Learning Curve für Random Forest...
# Learning Curve gespeichert unter: results/Materialprognose//aggregated_features/Random Forest/learning_curve_Random Forest.svg
# Analysiere Modell: SVM...
# Erstelle Validation Curve für SVM...
# Validation Curve gespeichert unter: results/Materialprognose//aggregated_features/SVM/validation_curve_SVM_clf__C.svg
# Erstelle Learning Curve für SVM...
# Learning Curve gespeichert unter: results/Materialprognose//aggregated_features/SVM/learning_curve_SVM.svg
# Analysiere Modell: kNN...
# Erstelle Validation Curve für kNN...
# Validation Curve gespeichert unter: results/Materialprognose//aggregated_features/kNN/validation_curve_kNN_clf__n_neighbors.svg
# Erstelle Learning Curve für kNN...
# Learning Curve gespeichert unter: results/Materialprognose//aggregated_features/kNN/learning_curve_kNN.svg
# Analysiere Modell: Logistische Regression...
# Erstelle Validation Curve für Logistische Regression...
# Validation Curve gespeichert unter: results/Materialprognose//aggregated_features/Logistische Regression/validation_curve_Logistische Regression_clf__C.svg
# /opt/anaconda3/envs/conda310/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# Erstelle Learning Curve für Logistische Regression...
# /opt/anaconda3/envs/conda310/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# Learning Curve gespeichert unter: results/Materialprognose//aggregated_features/Logistische Regression/learning_curve_Logistische Regression.svg

# %% [markdown]
# ## SHAP-Analyse

# %%
# SHAP-Analyse
if shap_on:
    shap_analysis(
    best_pipelines=best_pipelines,  # Das Dictionary der besten Pipelines
    X_train=X_train,  # Die Trainingsdaten
    target_name = target_name,  # Der Zielname, z. B. für das Modellieren des Zielwerts
    dataset_name= dataset_name,  # Der Name des Datensets
    output_dir= target_dir,  # Optional: Basisverzeichnis für die Ergebnisse
    plot_type=plot_type,
    save_plots=save_plots,  # Angabe, ob die Diagramme gespeichert werden sollen
    verkippung = Verkippung
)
    #starting_shap

# %%
# Alle Diagramme aus der Zielgröße laden
display_top_models_for_target(
    target_dir,
    results_df_2,
    metric,
    verkippung=Verkippung,
    top_n=3  # Nur die besten 3 Modelle anzeigen
)
# Out:
# Top-3 Modelle basierend auf der Metrik 'f1_weighted':
# AdaBoost         0.944224
# Random Forest    0.944224
# SVM              0.917797
# Name: f1_weighted, dtype: object
#
# Top-3 Modelle basierend auf der gewichteten Metrik 'f1_weighted':
# AdaBoost         0.944224
# Random Forest    0.944224
# SVM              0.917797
# Name: f1_weighted, dtype: object
#
# Top-3 Modelle basierend auf der gewichteten Metrik 'percent_diff_f1_weighted':
# kNN                       11.729821
# XGBoost                    9.464208
# Logistische Regression     5.684452
# Name: percent_diff_f1_weighted, dtype: object
#
# Anzeigen der SHAP-Diagramme für Modelle in den Top-3 (zusammengefasst): Random Forest, SVM, Logistische Regression, XGBoost, kNN, AdaBoost
# SHAP-Diagramm für Random Forest nicht gefunden unter results/Materialprognose//aggregated_features/Random Forest/shap_summary_Random Forest.svg.
# SHAP-Diagramm für SVM nicht gefunden unter results/Materialprognose//aggregated_features/SVM/shap_summary_SVM.svg.
# SHAP-Diagramm für Logistische Regression nicht gefunden unter results/Materialprognose//aggregated_features/Logistische Regression/shap_summary_Logistische Regression.svg.
# SHAP-Diagramm für XGBoost nicht gefunden unter results/Materialprognose//aggregated_features/XGBoost/shap_summary_XGBoost.svg.
# SHAP-Diagramm für kNN nicht gefunden unter results/Materialprognose//aggregated_features/kNN/shap_summary_kNN.svg.
# SHAP-Diagramm für AdaBoost nicht gefunden unter results/Materialprognose//aggregated_features/AdaBoost/shap_summary_AdaBoost.svg.

# %% [markdown]
# # New Features Dataset

# %%
# Einstellungen
dataset_name = "new_features"

target_dir, feature_importance_path, balance_suffix, feature_importance_path_best, target_dir_best, tilt_suffix, temp_suffix  = direcetion_results(dataset_name, target_name, smote_on, Verkippung, bauteil_temp)

# X_train und X_test auf relevante Spalten beschränken
X_train = X_train_original
X_test = X_test_original

# %% [markdown]
# ## Training

# %%
# Modelltraining und Bewertung
best_pipelines, results, confusion_matrices3 = train_and_tune_models_balanced(pipelines, 
    param_grids, 
    X_train, 
    y_train, 
    skf, 
    X_test=X_test, 
    y_test=y_test
)

# Ergebnisse in DataFrame speichern
results_df_3 = pd.DataFrame.from_dict(results, orient='index').T
#results_df.drop(['best_params'], axis=0, inplace=True)

# Ergebnisse in tabellarischer Form anzeigen
display(HTML(results_df_3.to_html()))

save_scores_to_csv(
    results=results_df_3,  # DataFrame mit den Scores
    output_dir=target_dir,
    file_name=f"model_scores_{dataset_name}{balance_suffix}.csv",  # Gemeinsamer Basisname
    Verkippung=Verkippung  # Fügt den '_no_tilt'-Suffix hinzu, falls nötig
)
# Out:
# Training XGBoost...
# Fitting 5 folds for each of 81 candidates, totalling 405 fits
# Berechnung der finalen Scores für XGBoost...
# Training AdaBoost...
# Fitting 5 folds for each of 18 candidates, totalling 90 fits
# Berechnung der finalen Scores für AdaBoost...
# Training Random Forest...
# Fitting 5 folds for each of 81 candidates, totalling 405 fits
# Berechnung der finalen Scores für Random Forest...
# Training SVM...
# Fitting 5 folds for each of 9 candidates, totalling 45 fits
# Berechnung der finalen Scores für SVM...
# Training kNN...
# Fitting 5 folds for each of 4 candidates, totalling 20 fits
# Berechnung der finalen Scores für kNN...
# Training Logistische Regression...
# Fitting 5 folds for each of 16 candidates, totalling 80 fits
# /opt/anaconda3/envs/conda310/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/anaconda3/envs/conda310/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/anaconda3/envs/conda310/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/anaconda3/envs/conda310/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/anaconda3/envs/conda310/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/anaconda3/envs/conda310/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/anaconda3/envs/conda310/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/anaconda3/envs/conda310/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/anaconda3/envs/conda310/lib/python3.10/site-packages/joblib/externals/loky/process_executor.py:752: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   warnings.warn(
# /opt/anaconda3/envs/conda310/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/anaconda3/envs/conda310/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/anaconda3/envs/conda310/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/anaconda3/envs/conda310/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/anaconda3/envs/conda310/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/anaconda3/envs/conda310/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/anaconda3/envs/conda310/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/anaconda3/envs/conda310/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/anaconda3/envs/conda310/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/anaconda3/envs/conda310/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/anaconda3/envs/conda310/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/anaconda3/envs/conda310/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/anaconda3/envs/conda310/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/anaconda3/envs/conda310/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/anaconda3/envs/conda310/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/anaconda3/envs/conda310/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/anaconda3/envs/conda310/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/anaconda3/envs/conda310/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/anaconda3/envs/conda310/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/anaconda3/envs/conda310/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/anaconda3/envs/conda310/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/anaconda3/envs/conda310/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/anaconda3/envs/conda310/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/anaconda3/envs/conda310/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/anaconda3/envs/conda310/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/anaconda3/envs/conda310/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/anaconda3/envs/conda310/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/anaconda3/envs/conda310/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/anaconda3/envs/conda310/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/anaconda3/envs/conda310/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/anaconda3/envs/conda310/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/anaconda3/envs/conda310/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# Berechnung der finalen Scores für Logistische Regression...
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>XGBoost</th>
#       <th>AdaBoost</th>
#       <th>Random Forest</th>
#       <th>SVM</th>
#       <th>kNN</th>
#       <th>Logistische Regression</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>accuracy</th>
#       <td>0.91129</td>
#       <td>0.951613</td>
#       <td>0.919355</td>
#       <td>0.935484</td>
#       <td>0.870968</td>
#       <td>0.879032</td>
#     </tr>
#     <tr>
#       <th>precision</th>
#       <td>0.964286</td>
#       <td>0.977011</td>
#       <td>0.975904</td>
#       <td>0.955056</td>
#       <td>0.986667</td>
#       <td>0.930233</td>
#     </tr>
#     <tr>
#       <th>recall</th>
#       <td>0.910112</td>
#       <td>0.955056</td>
#       <td>0.910112</td>
#       <td>0.955056</td>
#       <td>0.831461</td>
#       <td>0.898876</td>
#     </tr>
#     <tr>
#       <th>f1</th>
#       <td>0.936416</td>
#       <td>0.965909</td>
#       <td>0.94186</td>
#       <td>0.955056</td>
#       <td>0.902439</td>
#       <td>0.914286</td>
#     </tr>
#     <tr>
#       <th>f1_weighted</th>
#       <td>0.912965</td>
#       <td>0.95201</td>
#       <td>0.921132</td>
#       <td>0.935484</td>
#       <td>0.876213</td>
#       <td>0.880481</td>
#     </tr>
#     <tr>
#       <th>roc_auc</th>
#       <td>0.95313</td>
#       <td>0.965811</td>
#       <td>0.96565</td>
#       <td>0.970787</td>
#       <td>0.901445</td>
#       <td>0.943178</td>
#     </tr>
#     <tr>
#       <th>percent_diff_accuracy</th>
#       <td>8.870968</td>
#       <td>4.83871</td>
#       <td>7.079559</td>
#       <td>4.072614</td>
#       <td>12.903226</td>
#       <td>7.509232</td>
#     </tr>
#     <tr>
#       <th>percent_diff_precision</th>
#       <td>3.571429</td>
#       <td>2.298851</td>
#       <td>2.409639</td>
#       <td>2.641817</td>
#       <td>1.333333</td>
#       <td>2.382518</td>
#     </tr>
#     <tr>
#       <th>percent_diff_recall</th>
#       <td>8.988764</td>
#       <td>4.494382</td>
#       <td>7.017536</td>
#       <td>1.459329</td>
#       <td>16.853933</td>
#       <td>5.141789</td>
#     </tr>
#     <tr>
#       <th>percent_diff_f1</th>
#       <td>6.358382</td>
#       <td>3.409091</td>
#       <td>4.793957</td>
#       <td>2.050573</td>
#       <td>9.756098</td>
#       <td>3.785805</td>
#     </tr>
#     <tr>
#       <th>percent_diff_f1_weighted</th>
#       <td>8.703462</td>
#       <td>4.798998</td>
#       <td>6.899868</td>
#       <td>4.072526</td>
#       <td>12.378704</td>
#       <td>7.356756</td>
#     </tr>
#     <tr>
#       <th>percent_diff_roc_auc</th>
#       <td>4.686998</td>
#       <td>3.418941</td>
#       <td>3.434992</td>
#       <td>2.784983</td>
#       <td>9.855538</td>
#       <td>4.794641</td>
#     </tr>
#     <tr>
#       <th>best_params</th>
#       <td>{'clf__gamma': 0.05, 'clf__learning_rate': 0.05, 'clf__max_depth': 8, 'clf__n_estimators': 70}</td>
#       <td>{'clf__estimator': DecisionTreeClassifier(max_depth=4), 'clf__learning_rate': 0.25, 'clf__n_estimators': 21}</td>
#       <td>{'clf__max_depth': 7, 'clf__min_samples_leaf': 2, 'clf__min_samples_split': 3, 'clf__n_estimators': 60}</td>
#       <td>{'clf__C': 0.5, 'clf__gamma': 0.01, 'clf__kernel': 'rbf'}</td>
#       <td>{'clf__n_neighbors': 3, 'clf__weights': 'uniform'}</td>
#       <td>{'clf__C': 50, 'clf__max_iter': 500, 'clf__solver': 'lbfgs'}</td>
#     </tr>
#   </tbody>
# </table>
# Scores erfolgreich gespeichert unter: results/Materialprognose//new_features/model_scores_new_features.csv

# %% [markdown]
# ## Confusion Matrices

# %%
# Normalisierte durchschnittliche Confusion-Matrices anzeigen
display_final_confusion_matrices(
    confusion_matrices3,
    label_mapping_path=label_mapping_path,
    target_column=target_column,  # Zielspalte hinzufügen
    target_dir=target_dir,
    save_plots=save_plots,
    normalize=True,  # Optional
    Verkippung=Verkippung
)
# Out:
# Confusion-Matrix für XGBoost (Testdaten):
# Confusion-Matrix für XGBoost gespeichert unter: results/Materialprognose//new_features/XGBoost/final_confusion_matrix.svg
# Confusion-Matrix für AdaBoost (Testdaten):
# Confusion-Matrix für AdaBoost gespeichert unter: results/Materialprognose//new_features/AdaBoost/final_confusion_matrix.svg
# Confusion-Matrix für Random Forest (Testdaten):
# Confusion-Matrix für Random Forest gespeichert unter: results/Materialprognose//new_features/Random Forest/final_confusion_matrix.svg
# Confusion-Matrix für SVM (Testdaten):
# Confusion-Matrix für SVM gespeichert unter: results/Materialprognose//new_features/SVM/final_confusion_matrix.svg
# Confusion-Matrix für kNN (Testdaten):
# Confusion-Matrix für kNN gespeichert unter: results/Materialprognose//new_features/kNN/final_confusion_matrix.svg
# Confusion-Matrix für Logistische Regression (Testdaten):
# Confusion-Matrix für Logistische Regression gespeichert unter: results/Materialprognose//new_features/Logistische Regression/final_confusion_matrix.svg

# %% [markdown]
# ## Overfitting Test

# %%
# Analyse von Learning Curves für Bias-Variance-Tradeoff
print(f"\nLearning Curve Analyse für {target_name}:")

# Analyse der Modellleistung
analyze_model_performance(
    pipelines=pipelines, 
    param_grids=param_grids, 
    X=X_train, 
    y=y_train, 
    scoring='f1', 
    cv=skf,
    save_plots=save_plots,
    output_dir= target_dir,
    Verkippung=Verkippung
)
# Out:
# Learning Curve Analyse für Materialprognose:
# Analysiere Modell: XGBoost...
# Erstelle Validation Curve für XGBoost...
# /opt/anaconda3/envs/conda310/lib/python3.10/site-packages/joblib/externals/loky/process_executor.py:752: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   warnings.warn(
# Validation Curve gespeichert unter: results/Materialprognose//new_features/XGBoost/validation_curve_XGBoost_clf__n_estimators.svg
# Erstelle Learning Curve für XGBoost...
# /opt/anaconda3/envs/conda310/lib/python3.10/site-packages/joblib/externals/loky/process_executor.py:752: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   warnings.warn(
# Learning Curve gespeichert unter: results/Materialprognose//new_features/XGBoost/learning_curve_XGBoost.svg
# Analysiere Modell: AdaBoost...
# Erstelle Validation Curve für AdaBoost...
# Validation Curve gespeichert unter: results/Materialprognose//new_features/AdaBoost/validation_curve_AdaBoost_clf__n_estimators.svg
# Erstelle Learning Curve für AdaBoost...
# Learning Curve gespeichert unter: results/Materialprognose//new_features/AdaBoost/learning_curve_AdaBoost.svg
# Analysiere Modell: Random Forest...
# Erstelle Validation Curve für Random Forest...
# Validation Curve gespeichert unter: results/Materialprognose//new_features/Random Forest/validation_curve_Random Forest_clf__n_estimators.svg
# Erstelle Learning Curve für Random Forest...
# Learning Curve gespeichert unter: results/Materialprognose//new_features/Random Forest/learning_curve_Random Forest.svg
# Analysiere Modell: SVM...
# Erstelle Validation Curve für SVM...
# Validation Curve gespeichert unter: results/Materialprognose//new_features/SVM/validation_curve_SVM_clf__C.svg
# Erstelle Learning Curve für SVM...
# Learning Curve gespeichert unter: results/Materialprognose//new_features/SVM/learning_curve_SVM.svg
# Analysiere Modell: kNN...
# Erstelle Validation Curve für kNN...
# Validation Curve gespeichert unter: results/Materialprognose//new_features/kNN/validation_curve_kNN_clf__n_neighbors.svg
# Erstelle Learning Curve für kNN...
# Learning Curve gespeichert unter: results/Materialprognose//new_features/kNN/learning_curve_kNN.svg
# Analysiere Modell: Logistische Regression...
# Erstelle Validation Curve für Logistische Regression...
# Validation Curve gespeichert unter: results/Materialprognose//new_features/Logistische Regression/validation_curve_Logistische Regression_clf__C.svg
# Erstelle Learning Curve für Logistische Regression...
# Learning Curve gespeichert unter: results/Materialprognose//new_features/Logistische Regression/learning_curve_Logistische Regression.svg

# %% [markdown]
# ## SHAP-Analyse

# %%
# SHAP-Analyse
if shap_on:
    shap_analysis(
    best_pipelines=best_pipelines,  # Das Dictionary der besten Pipelines
    X_train=X_train,  # Die Trainingsdaten
    target_name = target_name,  # Der Zielname, z. B. für das Modellieren des Zielwerts
    dataset_name= dataset_name,  # Der Name des Datensets
    output_dir= target_dir,  # Optional: Basisverzeichnis für die Ergebnisse
    plot_type=plot_type,
    save_plots=save_plots,  # Angabe, ob die Diagramme gespeichert werden sollen
    verkippung = Verkippung
)

# %%
# Alle Diagramme aus der Zielgröße laden
display_top_models_for_target(
    target_dir,
    results_df_3,
    metric,
    verkippung=Verkippung,
    top_n=3  # Nur die besten 3 Modelle anzeigen
)
# Out:
# Top-3 Modelle basierend auf der Metrik 'f1_weighted':
# AdaBoost          0.95201
# SVM              0.935484
# Random Forest    0.921132
# Name: f1_weighted, dtype: object
#
# Top-3 Modelle basierend auf der gewichteten Metrik 'f1_weighted':
# AdaBoost          0.95201
# SVM              0.935484
# Random Forest    0.921132
# Name: f1_weighted, dtype: object
#
# Top-3 Modelle basierend auf der gewichteten Metrik 'percent_diff_f1_weighted':
# kNN                       12.378704
# XGBoost                    8.703462
# Logistische Regression     7.356756
# Name: percent_diff_f1_weighted, dtype: object
#
# Anzeigen der SHAP-Diagramme für Modelle in den Top-3 (zusammengefasst): Random Forest, SVM, Logistische Regression, XGBoost, kNN, AdaBoost
# SHAP-Diagramm für Random Forest nicht gefunden unter results/Materialprognose//new_features/Random Forest/shap_summary_Random Forest.svg.
# SHAP-Diagramm für SVM nicht gefunden unter results/Materialprognose//new_features/SVM/shap_summary_SVM.svg.
# SHAP-Diagramm für Logistische Regression nicht gefunden unter results/Materialprognose//new_features/Logistische Regression/shap_summary_Logistische Regression.svg.
# SHAP-Diagramm für XGBoost nicht gefunden unter results/Materialprognose//new_features/XGBoost/shap_summary_XGBoost.svg.
# SHAP-Diagramm für kNN nicht gefunden unter results/Materialprognose//new_features/kNN/shap_summary_kNN.svg.
# SHAP-Diagramm für AdaBoost nicht gefunden unter results/Materialprognose//new_features/AdaBoost/shap_summary_AdaBoost.svg.

# %% [markdown]
# # Vergleich der Results

# %%
results_dfs = {
    "Process Features": results_df_1,
    "Aggregated Features": results_df_2,
    "New Features": results_df_3
}

# Vergleich der Ergebnisse über die Datasets hinweg
compare_metric = "f1_weighted"
comparison_table, best_combination = compare_results_across_datasets(results_dfs, metric="f1")

# Vergleichstabelle in HTML-Format konvertieren und anzeigen
print(f"Vergleich der {compare_metric}-Scores für die unterschiedlichen Datasets und Modelle:")
display(HTML(comparison_table.to_html()))

# Beste Kombination ausgeben
print(f"\nBeste Kombination:")
print(f"Dataset: {best_combination[0]}, Modell: {best_combination[1]}, Score: {best_combination[2]:.4f}")

save_scores_to_csv(
    results=comparison_table,
    output_dir=target_dir,
    file_name=f"compare_model_scores_{target_name}_{compare_metric}.csv",
    Verkippung=Verkippung
)
# Out:
# Vergleich der f1_weighted-Scores für die unterschiedlichen Datasets und Modelle:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Dataset</th>
#       <th>Process Features</th>
#       <th>Aggregated Features</th>
#       <th>New Features</th>
#     </tr>
#     <tr>
#       <th>Model</th>
#       <th></th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Random Forest</th>
#       <td>0.924855</td>
#       <td>0.960000</td>
#       <td>0.941860</td>
#     </tr>
#     <tr>
#       <th>AdaBoost</th>
#       <td>0.919540</td>
#       <td>0.960000</td>
#       <td>0.965909</td>
#     </tr>
#     <tr>
#       <th>XGBoost</th>
#       <td>0.919540</td>
#       <td>0.930233</td>
#       <td>0.936416</td>
#     </tr>
#     <tr>
#       <th>SVM</th>
#       <td>0.849162</td>
#       <td>0.945055</td>
#       <td>0.955056</td>
#     </tr>
#     <tr>
#       <th>kNN</th>
#       <td>0.848485</td>
#       <td>0.911243</td>
#       <td>0.902439</td>
#     </tr>
#     <tr>
#       <th>Logistische Regression</th>
#       <td>0.670886</td>
#       <td>0.918605</td>
#       <td>0.914286</td>
#     </tr>
#   </tbody>
# </table>
# Beste Kombination:
# Dataset: New Features, Modell: AdaBoost, Score: 0.9659
# Scores erfolgreich gespeichert unter: results/Materialprognose//new_features/compare_model_scores_Materialprognose_f1_weighted.csv

# %%
output_path = f"./results/{target_name}/{balance_suffix}{tilt_suffix}{temp_suffix}/compare_model_scores_{target_name}_{compare_metric}{balance_suffix}{tilt_suffix}{temp_suffix}.svg"

# Diagramm erstellen
plot_scores_and_percent_diff(results_dfs, target_name=target_name, output_path=output_path, y_lim=(0.5, 1.0), metric=metric)

# %% [markdown]
# # Reduktion der Features & Performance des Best Models
# - Das beste Modell wird nach der Feature Reduktion mit Hilfe der SHAP Values im Zielverzeichis gespeichert.

# %%
# Modell und Feature Datensatz auswählen
model_name = "SVM"
pipeline = best_pipelines[model_name]
dataset_name = "new_features"

target_dir, feature_importance_path, balance_suffix, feature_importance_path_best, target_dir_best, tilt_suffix, temp_suffix = direcetion_results(dataset_name, target_name, smote_on, Verkippung, bauteil_temp, model_name=model_name)

# Verzeichnis erstellen, falls es nicht existiert
os.makedirs(target_dir, exist_ok=True)

# %%
# SHAP-Analyse für ein einzelnes Modell
# shap_analysis_single_model(
#     model_name=model_name,
#     pipeline=pipeline,
#     X_train=X_train,
#     target_name=target_name,
#     dataset_name=dataset_name,
#     output_dir=target_dir_best,
#     plot_type=plot_type,
#     save_plots=save_plots,
#     verkippung=Verkippung
# )

# %%
#feature_importance_path_best = f"results/best_models/{target_name}/feature_importance_{model_name}.csv"

# %%
# **AUFRUF DER FUNKTION**
best_pipelines, retrain_results = filter_and_retrain_with_vif(
    model_name=model_name,
    pipeline=pipeline,
    X_train=X_train,
    X_test=X_test,
    y_train=y_train,
    y_test=y_test,
    feature_importance_path=feature_importance_path_best,
    param_grids=param_grids,
    cv=skf,
    scoring=metric,
    pareto_split=0.8,  
    correlation_threshold=0.9,  
    vif_threshold=200.0,  
    output_dir=target_dir_best,
    target_name=target_name,
    dataset_name=dataset_name,
    verkippung=Verkippung,
    is_regression=False,
    label_mapping_path=label_mapping_path,    # Neuer Parameter für Confusion-Matrix
    target_column=target_column          # Neuer Parameter für Confusion-Matri
)
# Out:
# Feature-Wichtigkeiten aus results/best_models//Materialprognose//feature_importance_SVM.csv geladen.
# Originale Trainingsdaten: (5000, 70), Testdaten: (124, 70)
# Reduzierte Trainingsdaten nach SHAP: (5000, 34), Testdaten: (124, 34)
# Reduzierte Trainingsdaten nach Korrelationsanalyse: (5000, 19), Testdaten: (124, 19)
# Reduzierte Trainingsdaten nach VIF-Analyse: (5000, 11), Testdaten: (124, 11)
#
# Entfernte hoch korrelierte Features: {'Verkippung_3_Max', 'Verkippung_3_Median', 'Geschwindigkeit_Ges_Max', 'Verkippung_1_Max', 'Presskraft_dyn_Max', 'max_druck', 'Verkippung_2_Max', 'Verkippung_4_Max', 'Motorstrom_Mean', 'beruehrungsdauer', 'Geschwindigkeit_Ges_Median', 'Verkippung_1_Median', 'auftreffzeitpunkt', 'Berührzeit', 'Stoesselhub_Min'}
#
# Entfernte Features wegen hohem VIF (> {vif_threshold}): {'Wegmessung_Min', 'min_motorstrom', 'Bauteil_Temp', 'Umformzeit', 'Motorstrom_Max', 'Wegmessung_Median', 'Tiefster_Punkt', 'max_motorstrom'}
#
# Korrelierte Feature-Paare (Korrelation > {correlation_threshold}):
# max_druck <--> Geschwindigkeit_Ges_Min (Korrelation: 0.90)
# beruehrungsdauer <--> Geschwindigkeit_Ges_Min (Korrelation: 0.91)
# Berührzeit <--> Geschwindigkeit_Ges_Min (Korrelation: 0.91)
# Motorstrom_Mean <--> Motorstrom_Std (Korrelation: 0.94)
# Geschwindigkeit_Ges_Min <--> max_druck (Korrelation: 0.90)
# Presskraft_dyn_Max <--> max_druck (Korrelation: 1.00)
# Stoesselhub_Min <--> max_druck (Korrelation: 0.91)
# max_druck <--> Presskraft_dyn_Max (Korrelation: 1.00)
# Stoesselhub_Min <--> Presskraft_dyn_Max (Korrelation: 0.92)
# Verkippung_1_Median <--> Wegmessung_Median (Korrelation: 0.91)
# Verkippung_3_Median <--> Wegmessung_Median (Korrelation: 0.91)
# Geschwindigkeit_Ges_Median <--> Umformzeit (Korrelation: 0.90)
# Geschwindigkeit_Ges_Max <--> Energie_Aufprall (Korrelation: 0.95)
# auftreffzeitpunkt <--> Energie_Aufprall (Korrelation: 0.96)
# Umformzeit <--> Geschwindigkeit_Ges_Median (Korrelation: 0.90)
# Verkippung_1_Max <--> Wegmessung_Min (Korrelation: 0.94)
# Verkippung_2_Max <--> Wegmessung_Min (Korrelation: 0.94)
# Verkippung_3_Max <--> Wegmessung_Min (Korrelation: 0.94)
# Verkippung_4_Max <--> Wegmessung_Min (Korrelation: 0.93)
# Motorstrom_Std <--> Motorstrom_Mean (Korrelation: 0.94)
# Wegmessung_Min <--> Verkippung_1_Max (Korrelation: 0.94)
# Verkippung_2_Max <--> Verkippung_1_Max (Korrelation: 0.99)
# Verkippung_3_Max <--> Verkippung_1_Max (Korrelation: 1.00)
# Verkippung_4_Max <--> Verkippung_1_Max (Korrelation: 0.99)
# Stoesselhub_Min <--> Verkippung_1_Max (Korrelation: 0.96)
# Wegmessung_Min <--> Verkippung_2_Max (Korrelation: 0.94)
# Verkippung_1_Max <--> Verkippung_2_Max (Korrelation: 0.99)
# Verkippung_3_Max <--> Verkippung_2_Max (Korrelation: 0.99)
# Verkippung_4_Max <--> Verkippung_2_Max (Korrelation: 1.00)
# Stoesselhub_Min <--> Verkippung_2_Max (Korrelation: 0.96)
# Energie_Aufprall <--> Geschwindigkeit_Ges_Max (Korrelation: 0.95)
# auftreffzeitpunkt <--> Geschwindigkeit_Ges_Max (Korrelation: 0.98)
# Wegmessung_Min <--> Verkippung_3_Max (Korrelation: 0.94)
# Verkippung_1_Max <--> Verkippung_3_Max (Korrelation: 1.00)
# Verkippung_2_Max <--> Verkippung_3_Max (Korrelation: 0.99)
# Verkippung_4_Max <--> Verkippung_3_Max (Korrelation: 0.99)
# Stoesselhub_Min <--> Verkippung_3_Max (Korrelation: 0.96)
# Energie_Aufprall <--> auftreffzeitpunkt (Korrelation: 0.96)
# Geschwindigkeit_Ges_Max <--> auftreffzeitpunkt (Korrelation: 0.98)
# Geschwindigkeit_Ges_Min <--> beruehrungsdauer (Korrelation: 0.91)
# Berührzeit <--> beruehrungsdauer (Korrelation: 1.00)
# Geschwindigkeit_Ges_Min <--> Berührzeit (Korrelation: 0.91)
# beruehrungsdauer <--> Berührzeit (Korrelation: 1.00)
# Wegmessung_Min <--> Verkippung_4_Max (Korrelation: 0.93)
# Verkippung_1_Max <--> Verkippung_4_Max (Korrelation: 0.99)
# Verkippung_2_Max <--> Verkippung_4_Max (Korrelation: 1.00)
# Verkippung_3_Max <--> Verkippung_4_Max (Korrelation: 0.99)
# Stoesselhub_Min <--> Verkippung_4_Max (Korrelation: 0.96)
# max_druck <--> Stoesselhub_Min (Korrelation: 0.91)
# Presskraft_dyn_Max <--> Stoesselhub_Min (Korrelation: 0.92)
# Verkippung_1_Max <--> Stoesselhub_Min (Korrelation: 0.96)
# Verkippung_2_Max <--> Stoesselhub_Min (Korrelation: 0.96)
# Verkippung_3_Max <--> Stoesselhub_Min (Korrelation: 0.96)
# Verkippung_4_Max <--> Stoesselhub_Min (Korrelation: 0.96)
# Wegmessung_Median <--> Verkippung_1_Median (Korrelation: 0.91)
# Verkippung_3_Median <--> Verkippung_1_Median (Korrelation: 1.00)
# Wegmessung_Median <--> Verkippung_3_Median (Korrelation: 0.91)
# Verkippung_1_Median <--> Verkippung_3_Median (Korrelation: 1.00)
#
# VIF-Werte vor der Reduktion:
#                     Feature          VIF
# 6         Wegmessung_Median  1533.907630
# 18           max_motorstrom   878.628302
# 11           Wegmessung_Min   725.957743
# 16           min_motorstrom   717.958589
# 7            Tiefster_Punkt   466.665914
# 9                Umformzeit   358.540196
# 0              Bauteil_Temp   241.008366
# 17           Motorstrom_Max   213.181669
# 1   Geschwindigkeit_Ges_Std   147.312458
# 4           tilt_y_tiefster   137.663468
# 10         Energie_Aufprall   119.593580
# 12    Presskraft_dyn_Median   112.258853
# 5            Motorstrom_Std   102.205702
# 14  Energie_ab_Durchschnitt    85.452859
# 2       Presskraft_dyn_Mean    47.631867
# 3   Geschwindigkeit_Ges_Min    25.808257
# 13                tilt_x_t0    18.544280
# 15       Presskraft_dyn_Min    11.039373
# 8           tilt_x_tiefster     2.090081
# Korrelations-Plot gespeichert unter: results/best_models/Materialprognose/correlation_plot_Materialprognose.svg
# VIF-Plot gespeichert unter: results/best_models/Materialprognose/vif_plot_Materialprognose.svg
# Feature-Werte gespeichert unter: results/best_models/Materialprognose/selected_features_Materialprognose.csv
# Korrelierte Feature-Paare gespeichert unter: results/best_models/Materialprognose/correlated_feature_pairs_Materialprognose.csv
# VIF-Werte vor der Reduktion gespeichert unter: results/best_models/Materialprognose/vif_before_reduction_Materialprognose.csv
# Training SVM...
# Fitting 5 folds for each of 9 candidates, totalling 45 fits
# Berechnung der finalen Scores für SVM...
# Training SVM...
# Fitting 5 folds for each of 9 candidates, totalling 45 fits
# Berechnung der finalen Scores für SVM...
# Confusion-Matrix für SVM (Testdaten):
# Confusion-Matrix für SVM gespeichert unter: results/best_models/Materialprognose/SVM/final_confusion_matrix.svg
# Modell für Materialprognose gespeichert unter: results/best_models/Materialprognose/MaterialprognoseModel.pkl
# Feature-Namen gespeichert unter: results/best_models/Materialprognose/MaterialprognoseModel_features.txt
# Scores erfolgreich gespeichert unter: results/best_models/Materialprognose/model_scores_best_model_Materialprognose.csv
# Training SVM...
# Fitting 5 folds for each of 9 candidates, totalling 45 fits
# Berechnung der finalen Scores für SVM...
# Training SVM...
# Fitting 5 folds for each of 9 candidates, totalling 45 fits
# Berechnung der finalen Scores für SVM...
# Ergebnistabelle gespeichert unter: results/best_models/Materialprognose/summary_feature_selection_Materialprognose.csv

# %% [markdown]
# # Visualisierung der Ergebnisse

# %% [markdown]
# ## SMOTE für Prozess Features

# %%
smote_path = f"./results/{target_name}/{tilt_suffix}{temp_suffix}/process_features/model_scores_process_features.csv"
no_smote_path = f"./results/{target_name}/noSMOTE{tilt_suffix}{temp_suffix}/process_features/model_scores_process_featuresnoSMOTE.csv"
output_path = f"./results/{target_name}/compare_SMOTE_process_features_{target_name}_{compare_metric}.svg"
df_comp = compare_smote_effects(no_smote_path, smote_path, metric=metric, title=f"Vergleich der Fehlermetrik für das Prozess Feature-Set: No SMOTE vs. SMOTE", save_path=output_path)
# Out:
# Plot gespeichert unter: ./results/Materialprognose/compare_SMOTE_process_features_Materialprognose_f1_weighted.svg
